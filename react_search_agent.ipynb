# %%
from langchain_groq import ChatGroq
from langchain.tools import tool
from langchain.agents import create_agent
from langchain_core.messages import HumanMessage
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
@tool
def get_weather(query: str) -> str:
    """
    Tool Searches over Internet
    
    Args:
        query: The search query
    Returns:
        The search results
    """
    print(f"Searching for: {query}")
    return "Hyderabad weather is sunny"

# %%
llm = ChatGroq(model="llama-3.3-70b-versatile")

# %%
tools = [get_weather]

# %%
search_agent = create_agent(model=llm, tools=tools)

# %%
response = search_agent.invoke({"messages" : HumanMessage(content="What is the weather in Hyderabad?")})
# Out:
# Searching for: Hyderabad weather
# Searching for: Hyderabad temperature

# %%
print(response)
# Out:
# {'messages': [HumanMessage(content='What is the weather in Hyderabad?', additional_kwargs={}, response_metadata={}, id='c9124a45-d759-48d8-b0a2-4e7dfd6e5d0a'), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'qzw5mb7ty', 'function': {'arguments': '{"query":"Hyderabad weather"}', 'name': 'get_weather'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 16, 'prompt_tokens': 250, 'total_tokens': 266, 'completion_time': 0.027657524, 'completion_tokens_details': None, 'prompt_time': 0.030343612, 'prompt_tokens_details': None, 'queue_time': 0.049273668, 'total_time': 0.058001136}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_dae98b5ecb', 'service_tier': 'on_demand', 'finish_reason': 'tool_calls', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019c4649-c4ec-73b2-a3e2-0cacc385ff25-0', tool_calls=[{'name': 'get_weather', 'args': {'query': 'Hyderabad weather'}, 'id': 'qzw5mb7ty', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 250, 'output_tokens': 16, 'total_tokens': 266}), ToolMessage(content='Hyderabad weather is sunny', name='get_weather', id='f5aa8b6e-9341-417b-9b4d-84d267ba75c0', tool_call_id='qzw5mb7ty'), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'c05f9h287', 'function': {'arguments': '{"query":"Hyderabad temperature"}', 'name': 'get_weather'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 16, 'prompt_tokens': 281, 'total_tokens': 297, 'completion_time': 0.035785866, 'completion_tokens_details': None, 'prompt_time': 0.014517654, 'prompt_tokens_details': None, 'queue_time': 0.048610916, 'total_time': 0.05030352}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_dae98b5ecb', 'service_tier': 'on_demand', 'finish_reason': 'tool_calls', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019c4649-c658-76a3-bc8e-8e4c2d2faf56-0', tool_calls=[{'name': 'get_weather', 'args': {'query': 'Hyderabad temperature'}, 'id': 'c05f9h287', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 281, 'output_tokens': 16, 'total_tokens': 297}), ToolMessage(content='Hyderabad weather is sunny', name='get_weather', id='5fd5a9f6-6ade-4fce-9854-e921cdefb796', tool_call_id='c05f9h287'), AIMessage(content='The current weather in Hyderabad is sunny.', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 9, 'prompt_tokens': 312, 'total_tokens': 321, 'completion_time': 0.040827655, 'completion_tokens_details': None, 'prompt_time': 0.015875103, 'prompt_tokens_details': None, 'queue_time': 0.047905087, 'total_time': 0.056702758}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_68f543a7cc', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019c4649-c726-7c90-bbdc-c4da0bb1bf24-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 312, 'output_tokens': 9, 'total_tokens': 321})]}
