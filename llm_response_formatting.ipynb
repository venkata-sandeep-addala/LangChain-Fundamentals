# %%
from langchain_groq import ChatGroq
from langchain.agents import create_agent
from langchain_tavily import TavilySearch
from langchain_core.messages import HumanMessage
from pydantic import BaseModel, Field

# %%
class AgentResponse(BaseModel):
    """Schema for the agent's response."""
    answer: str = Field(..., description="The answer to the user's question.")
    source: str = Field(..., description="The source URL of the information used to answer the question.")

# %%
llm = ChatGroq(model="llama-3.3-70b-versatile")
tools = [TavilySearch(start_date="2026-02-01")]

# %%
agent = create_agent(model=llm, tools=tools, response_format=AgentResponse)

# %%
response = agent.invoke({"messages":HumanMessage(content="search for 3 job postings for an ai engineer using langchain in Hyderabad on linkedin and list their details?")})

# %%
print(response['messages'][-1].content)
# Out:
# Returning structured response: answer="Here are 3 job postings for an AI Engineer using LangChain in Hyderabad on LinkedIn: \n1. Job Title: AI Engineer - LangChain \nCompany: Microsoft \nLocation: Hyderabad, India \nJob Type: Full-time \nExperience: 5+ years \nJob Description: Design, develop, and deploy AI models using LangChain. \nRequirements: Master's degree in CS, 5+ years of experience in AI, expertise in LangChain. \n2. Job Title: Senior AI Engineer - LangChain \nCompany: Accenture \nLocation: Hyderabad, India \nJob Type: Full-time \nExperience: 8+ years \nJob Description: Lead the development of AI solutions using LangChain. \nRequirements: Bachelor's degree in CS, 8+ years of experience in AI, expertise in LangChain. \n3. Job Title: AI Engineer - LangChain \nCompany: Infosys \nLocation: Hyderabad, India \nJob Type: Full-time \nExperience: 3+ years \nJob Description: Develop and deploy AI models using LangChain. \nRequirements: Bachelor's degree in CS, 3+ years of experience 
# ...
